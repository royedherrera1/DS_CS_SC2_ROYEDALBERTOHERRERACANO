# %% [markdown]
# a. Extraer la información del archivo.

# %%
import pandas as pd
vaccination = pd.read_csv('/content/drive/MyDrive/Csv Python/0.8ddpr74xw650.udno6l076vcountry_vaccinations.csv')
vaccination.head(3)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
vaccination['date'] = pd.to_datetime(vaccination['date'])
vaccination.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
vacunas_por_compañia = vaccination.groupby('vaccines')['daily_vaccinations'].sum()
vacunas_por_compañia
# Out:
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Soberana02, Sputnik Light, Sputnik V                              9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                            201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02, Sputnik Light, Sputnik V                                                       37861146.0
# Abdala, Soberana Plus, Soberana02                                                                                              33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/AstraZeneca, Razi Cov Pars, Sinopharm/Beijing, Soberana02, SpikoGen, Sputnik V    146357015.0
#                                                                                                                                  ...
# Pfizer/BioNTech, Sinovac, Turkovac                                                                                            147484328.0
# Pfizer/BioNTech, Sputnik V                                                                                                        68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                                                                                           20891256.0
# Sinopharm/Beijing                                                                                                                893824.0
# Sinopharm/Beijing, Sputnik V                                                                                                   14398697.0
# Name: daily_vaccinations, Length: 84, dtype: float64

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
vacunas_mundo = vaccination['daily_vaccinations'].sum()
int(vacunas_mundo)
# Out:
# 11320239871

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
vacunas_pais_promedio = vaccination.groupby('country')['daily_vaccinations'].mean()
vacunas_pais_promedio
# Out:
# country
# Afghanistan          14610.681934
# Albania               6276.210046
# Algeria              33904.356436
# Andorra                367.716019
# Angola               44821.457584
#                          ...
# Wales                15518.411765
# Wallis and Futuna       33.886486
# Yemen                 2556.115756
# Zambia                9649.805158
# Zimbabwe             21669.066832
# Name: daily_vaccinations, Length: 223, dtype: float64

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
vacunas_29 = vaccination[vaccination['date']=='2021-01-29']
total_vacunas_29 = vacunas_29['daily_vaccinations'].sum()
total_vacunas_29
# Out:
# np.float64(4884052.0)

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = vaccination.copy()
conDiferencias['date'] = pd.to_datetime(conDiferencias['date'])
conDiferencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB

# %%
conDiferencias['diferencias'] = conDiferencias['daily_vaccinations'] - conDiferencias['daily_vaccinations_raw']
conDiferencias.sample(3)
# Out:
#                 country iso_code       date  total_vaccinations  \
# 14235        Cape Verde      CPV 2022-03-15                 NaN
# 28170             Gabon      GAB 2022-02-01                 NaN
# 60913  Papua New Guinea      PNG 2021-12-27                 NaN
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 14235                NaN                      NaN                     NaN
# 28170                NaN                      NaN                     NaN
# 60913                NaN                      NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 14235              1019.0                             NaN
# 28170              1933.0                             NaN
# 60913               459.0                             NaN
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 14235                            NaN                                  NaN
# 28170                            NaN                                  NaN
# 60913                            NaN                                  NaN
#
#        daily_vaccinations_per_million  \
# 14235                          1813.0
# 28170                           848.0
# 60913                            50.0
#
#                                                 vaccines  \
# 14235  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, ...
# 28170      Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 60913                                 Oxford/AstraZeneca
#
#                                              source_name  \
# 14235                          World Health Organization
# 28170  Africa Centres for Disease Control and Prevention
# 60913                         SPC Public Health Division
#
#                                           source_website  diferencias
# 14235                           https://covid19.who.int/          NaN
# 28170        https://africacdc.org/covid-19-vaccination/          NaN
# 60913  https://stats.pacificdata.org/vis?tm=covid&pg=...          NaN

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
print(f'Fecha mas antigua registrada: {conDiferencias['date'].min()}')
print(f'Fecha mas reciente registrada: {conDiferencias['date'].max()}')
print(f'Periodo de tiempo entre la fecha mas antigua y las mas reciente: {conDiferencias['date'].max() - conDiferencias['date'].min()}')
# Out:
# Fecha mas antigua registrada: 2020-12-02 00:00:00
# Fecha mas reciente registrada: 2022-03-29 00:00:00
# Periodo de tiempo entre la fecha mas antigua y las mas reciente: 482 days 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
conCantidad = vaccination.copy()
conCantidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB

# %%
conCantidad['canVac'] = conCantidad['vaccines'].str.split(', ').str.len()
conCantidad.head(3)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  canVac
# 0  World Health Organization  https://covid19.who.int/       4
# 1  World Health Organization  https://covid19.who.int/       4
# 2  World Health Organization  https://covid19.who.int/       4

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = vaccination.copy()
antes20 = antes20[antes20['date'] < '2020-12-20']
antes20.sample(3)
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0
# 58531  Norway      NOR 2020-12-16                18.0               18.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
# 58531                      NaN                     5.0                 2.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 13406                            0.02                           0.02
# 13407                            0.03                           0.03
# 58531                            0.00                           0.00
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 13406                                  NaN                            64.0
# 13407                                  NaN                            74.0
# 58531                                  NaN                             0.0
#
#                                                 vaccines  \
# 13406  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13407  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 58531                           Moderna, Pfizer/BioNTech
#
#                                              source_name  \
# 13406  Official data from provinces via covid19tracke...
# 13407  Official data from provinces via covid19tracke...
# 58531               Norwegian Institute of Public Health
#
#                                           source_website
# 13406  https://covid19tracker.ca/vaccinationtracker.html
# 13407  https://covid19tracker.ca/vaccinationtracker.html
# 58531  https://github.com/folkehelseinstituttet/surve...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = vaccination.copy()
pfizer = pfizer[pfizer['vaccines'].str.contains('Pfizer',case=False)]
pfizer.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter('resultadosReto.xlsx') as writer:
  conDiferencias.to_excel(writer, sheet_name='conDiferencias',index=False)
  conCantidad.to_excel(writer, sheet_name='conCantidad',index=False)
  antes20.to_excel(writer, sheet_name='antes20',index=False)
  pfizer.to_excel(writer, sheet_name='pfizer',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4076477331.py in <cell line: 0>()
#       1 with pd.ExcelWriter('resultadosReto.xlsx') as writer:
# ----> 2   conDiferencias.to_excel(writer, sheet_name='conDiferencias',index=False)
#       3   conCantidad.to_excel(writer, sheet_name='conCantidad',index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2416         )
# -> 2417         formatter.write(
#    2418             excel_writer,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     951         try:
# --> 952             writer._write_cells(
#     953                 formatted_cells,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_openpyxl.py in _write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     486         for cell in cells:
# --> 487             xcell = wks.cell(
#     488                 row=startrow + cell.row + 1, column=startcol + cell.col + 1
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/worksheet.py in cell(self, row, column, value)
#     243
# --> 244         cell = self._get_cell(row, column)
#     245         if value is not None:
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/worksheet.py in _get_cell(self, row, column)
#     260             cell = Cell(self, row=row, column=column)
# --> 261             self._add_cell(cell)
#     262         return self._cells[coordinate]
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/worksheet.py in _add_cell(self, cell)
#     270         row = cell.row
# --> 271         self._current_row = max(row, self._current_row)
#     272         self._cells[(row, column)] = cell
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4076477331.py in <cell line: 0>()
# ----> 1 with pd.ExcelWriter('resultadosReto.xlsx') as writer:
#       2   conDiferencias.to_excel(writer, sheet_name='conDiferencias',index=False)
#       3   conCantidad.to_excel(writer, sheet_name='conCantidad',index=False)
#       4   antes20.to_excel(writer, sheet_name='antes20',index=False)
#       5   pfizer.to_excel(writer, sheet_name='pfizer',index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __exit__(self, exc_type, exc_value, traceback)
#    1351         traceback: TracebackType | None,
#    1352     ) -> None:
# -> 1353         self.close()
#    1354
#    1355     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in close(self)
#    1355     def close(self) -> None:
#    1356         """synonym for save, to make it more file-like"""
# -> 1357         self._save()
#    1358         self._handles.close()
#    1359
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_openpyxl.py in _save(self)
#     108         Save workbook to disk.
#     109         """
# --> 110         self.book.save(self._handles.handle)
#     111         if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112             # truncate file to the written content
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/workbook.py in save(self, filename)
#     384         if self.write_only and not self.worksheets:
#     385             self.create_sheet()
# --> 386         save_workbook(self, filename)
#     387
#     388
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in save_workbook(workbook, filename)
#     292     workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293     writer = ExcelWriter(workbook, archive)
# --> 294     writer.save()
#     295     return True
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in save(self)
#     273     def save(self):
#     274         """Write data into the archive."""
# --> 275         self.write_data()
#     276         self._archive.close()
#     277
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in write_data(self)
#      75             self.manifest.append(custom_override)
#      76
# ---> 77         self._write_worksheets()
#      78         self._write_chartsheets()
#      79         self._write_images()
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in _write_worksheets(self)
#     213
#     214             ws._id = idx
# --> 215             self.write_worksheet(ws)
#     216
#     217             if ws._drawing:
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in write_worksheet(self, ws)
#     198         else:
#     199             writer = WorksheetWriter(ws)
# --> 200             writer.write()
#     201
#     202         ws._rels = writer._rels
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_writer.py in write(self)
#     357         """
#     358         self.write_top()
# --> 359         self.write_rows()
#     360         self.write_tail()
#     361         self.close()
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_writer.py in write_rows(self)
#     123         with xf.element("sheetData"):
#     124             for row_idx, row in self.rows():
# --> 125                 self.write_row(xf, row, row_idx)
#     126
#     127         self.xf.send(None) # return control to generator
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_writer.py in write_row(self, xf, row, row_idx)
#     145                     ):
#     146                     continue
# --> 147                 write_cell(xf, self.ws, cell, cell.has_style)
#     148
#     149
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/cell/_writer.py in lxml_write_cell(xf, worksheet, cell, styled)
#      88
#      89 def lxml_write_cell(xf, worksheet, cell, styled=False):
# ---> 90     value, attributes = _set_attributes(cell, styled)
#      91
#      92     if value == '' or value is None:
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/cell/_writer.py in _set_attributes(cell, styled)
#      35         else:
#      36             attrs['t'] = "n"
# ---> 37             value = to_excel(value, cell.parent.parent.epoch)
#      38
#      39     if cell.hyperlink:
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/utils/datetime.py in to_excel(dt, epoch)
#      92
#      93     # rebase on epoch and adjust for < 1900-03-01
# ---> 94     days = (dt - epoch).days
#      95     if 0 < days <= 60 and epoch == WINDOWS_EPOCH:
#      96         days -= 1
#
# timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__sub__()
#
# timedeltas.pyx in pandas._libs.tslibs.timedeltas._Timedelta._from_value_and_reso()
#
# timedeltas.pyx in pandas._libs.tslibs.timedeltas._timedelta_from_value_and_reso()
#
# KeyboardInterrupt:
